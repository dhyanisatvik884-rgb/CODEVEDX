# %% [markdown]
# # Exploratory Data Analysis (EDA) using Python

# %% [markdown]
# ## Overview
# In this section, we build upon our clean dataset to perform Exploratory Data Analysis (EDA). The objective is to look deeper into the data to discover hidden patterns, check statistical distributions, and analyze relationships between different variables.The following libraries are used for the analysis and advanced visualizations:
#
# * Numpy
# * Pandas
# * Matplotlib
# * Seaborn

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# **1. Importing our desired libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <br>

# %% [markdown]
# **2. Loading the dataset of our csv file**

# %%
data = pd.read_csv("dataset.csv")
df = pd.DataFrame(data)
print(df)
# Out:
#     EmployeeID     Name Department   Age    Salary  Experience       City
# 0          101     Amit         IT  25.0   55000.0         2.0      Delhi
# 1          102    Priya         HR  29.0   60000.0         NaN     Mumbai
# 2          103    Rahul         IT  31.0   75000.0         7.0  Bangalore
# 3          104     Neha    Finance   NaN   65000.0         3.0      Delhi
# 4          105    Karan         IT  35.0   90000.0        10.0        NaN
# 5          106   Anjali         HR  24.0       NaN         1.0     Mumbai
# 6          107    Vikas    Finance  40.0  110000.0        15.0  Bangalore
# 7          108    Meera        NaN  28.0   70000.0         5.0      Delhi
# 8          109    Arjun  Marketing  30.0   68000.0         NaN       Pune
# 9          110    Sneha  Marketing  26.0   62000.0         3.0     Mumbai
# 10         111    Rohan         IT  32.0   80000.0         8.0      Delhi
# 11         112    Kavya         HR  27.0   58000.0         4.0        NaN
# ...

# %% [markdown]
# <br>

# %% [markdown]
# **3. **
